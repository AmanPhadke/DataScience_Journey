# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
path = r"C:\Users\Asus\OneDrive\Desktop\Data Analysis Project 2\E-commerce Customer Behavior - Sheet1.csv"

# %%
df = pd.read_csv(path)
df = df.set_index("Customer ID")

# %%
ml_df = df.copy()

# %%
ml_df.head()
# Out:
#              Gender  Age           City Membership Type  Total Spend  \
# Customer ID
# 101          Female   29       New York            Gold      1120.20
# 102            Male   34    Los Angeles          Silver       780.50
# 103          Female   43        Chicago          Bronze       510.75
# 104            Male   30  San Francisco            Gold      1480.30
# 105            Male   27          Miami          Silver       720.40
#
#              Items Purchased  Average Rating  Discount Applied  \
# Customer ID
# 101                       14             4.6              True
# 102                       11             4.1             False
# 103                        9             3.4              True
# 104                       19             4.7             False
# 105                       13             4.0              True
#
#              Days Since Last Purchase Satisfaction Level
# Customer ID
# 101                                25          Satisfied
# 102                                18            Neutral
# 103                                42        Unsatisfied
# 104                                12          Satisfied
# 105                                55        Unsatisfied

# %%
print(ml_df.columns)
print(f"Dataset Size: Total {len(ml_df)} customers")
# Out:
# Index(['Gender', 'Age', 'City', 'Membership Type', 'Total Spend',
#        'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level'],
#       dtype='object')
# Dataset Size: Total 350 customers

# %%
target = 'Satisfaction Level'
ml_df[target].value_counts()
# Out:
# Satisfaction Level
# Satisfied      125
# Unsatisfied    116
# Neutral        107
# Name: count, dtype: int64

# %%
features = [ 
    'Age',
    'Total Spend',
    'Items Purchased',
    'Average Rating',
    'Days Since Last Purchase',
    'Gender',            #Needs encpding  
    'Membership Type',   #Needs encoding
    'Discount Applied'   #Needs encoding
]

ml_df = ml_df[features + [target]].copy()

print(f"Using {len(features)} features to find satisfaction")
# Out:
# Using 8 features to find satisfaction

# %% [markdown]
# ## Encoding the Nominal and Ordinal Variables

# %%
#For Genders and Discount applied we only have two possible outcomes: Male or Females and Yes or No.
#For these type of 2 outcome Nominal Variables we'll use the: Label Encoding

#Firstly we'll for an array of these 3 columns which we'll encode
categorical_cols = ['Gender', 'Membership Type', 'Discount Applied']

for col in categorical_cols:
    print(f"{col}: {ml_df[col].unique()}")

#Label Encoding
# Gender Encoding -> Male/Female = 0/1
ml_df["Encoded Gender"] = (ml_df['Gender'] == 'Male').astype(int)

# Discount Applied Encoding -> True/False = 1/0
ml_df["Encoded Discount"] = (ml_df['Discount Applied']).astype(int)


# One Hot Encoding 
dummies = pd.get_dummies(ml_df['Membership Type'], prefix='Membership').astype(int)
ml_df = pd.concat([dummies, ml_df], axis = 'columns')
# Out:
# Gender: ['Female' 'Male']
# Membership Type: ['Gold' 'Silver' 'Bronze']
# Discount Applied: [ True False]

# %%
ml_df
# Out:
#              Membership_Bronze  Membership_Gold  Membership_Silver  Age  \
# Customer ID
# 101                          0                1                  0   29
# 102                          0                0                  1   34
# 103                          1                0                  0   43
# 104                          0                1                  0   30
# 105                          0                0                  1   27
# ...                        ...              ...                ...  ...
# 446                          0                0                  1   32
# 447                          1                0                  0   36
# 448                          0                1                  0   30
# 449                          0                0                  1   34
# 450                          1                0                  0   43
#
#              Total Spend  Items Purchased  Average Rating  \
# Customer ID
# 101              1120.20               14             4.6
# 102               780.50               11             4.1
# 103               510.75                9             3.4
# 104              1480.30               19             4.7
# 105               720.40               13             4.0
# ...                  ...              ...             ...
# 446               660.30               10             3.8
# 447               470.50                8             3.0
# 448              1190.80               16             4.5
# 449               780.20               11             4.2
# 450               515.75               10             3.3
#
#              Days Since Last Purchase  Gender Membership Type  \
# Customer ID
# 101                                25  Female            Gold
# 102                                18    Male          Silver
# 103                                42  Female          Bronze
# 104                                12    Male            Gold
# 105                                55    Male          Silver
# ...                               ...     ...             ...
# 446                                42    Male          Silver
# 447                                27  Female          Bronze
# 448                                28  Female            Gold
# 449                                21    Male          Silver
# 450                                49  Female          Bronze
#
#              Discount Applied Satisfaction Level  Encoded Gender  \
# Customer ID
# 101                      True          Satisfied               0
# 102                     False            Neutral               1
# 103                      True        Unsatisfied               0
# 104                     False          Satisfied               1
# 105                      True        Unsatisfied               1
# ...                       ...                ...             ...
# 446                      True        Unsatisfied               1
# 447                     False            Neutral               0
# 448                      True          Satisfied               0
# 449                     False            Neutral               1
# 450                      True        Unsatisfied               0
#
#              Encoded Discount
# Customer ID
# 101                         1
# 102                         0
# 103                         1
# 104                         0
# 105                         1
# ...                       ...
# 446                         1
# 447                         0
# 448                         1
# 449                         0
# 450                         1
#
# [350 rows x 14 columns]
