# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanPhadke/DataScience_Journey/blob/main/Phase1/Week4_Pandas_Advanced/Deleting/Wine/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wine

# %% [markdown]
# ### Introduction:
#
# This exercise is a adaptation from the UCI Wine dataset.
# The only pupose is to practice deleting data with pandas.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called wine

# %%
wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data', sep=',')

# %% [markdown]
# ### Step 4. Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns

# %%
wine = wine.drop(wine.iloc[:, [0,3,6,8,10,12,13]], axis = 1)

# %% [markdown]
# ### Step 5. Assign the columns as below:
#
# The attributes are (donated by Riccardo Leardi, riclea '@' anchem.unige.it):
# 1) alcohol
# 2) malic_acid
# 3) alcalinity_of_ash
# 4) magnesium
# 5) flavanoids
# 6) proanthocyanins
# 7) hue

# %%
wine.columns = ['alcohol','malic_acid','alcalinity_of_ash', 'magnesium', 'flavanoids', 'proanthocyanins', 'hue']
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      13.20        1.78               11.2        100        2.76
# 1      13.16        2.36               18.6        101        3.24
# 2      14.37        1.95               16.8        113        3.49
# 3      13.24        2.59               21.0        118        2.69
# 4      14.20        1.76               15.2        112        3.39
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5         95        0.61
# 173    13.40        3.91               23.0        102        0.75
# 174    13.27        4.28               20.0        120        0.69
# 175    13.17        2.59               20.0        120        0.68
# 176    14.13        4.10               24.5         96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %% [markdown]
# ### Step 6. Set the values of the first 3 rows from alcohol as NaN

# %%
import numpy as np
wine.iloc[0:3] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 2      NaN         NaN                NaN        NaN         NaN
# 3    13.24        2.59               21.0      118.0        2.69
# 4    14.20        1.76               15.2      112.0        3.39
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 7. Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
wine.loc[3:4, 'magnesium'] = np.nan
wine.head()
# Out:
#    alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      NaN         NaN                NaN        NaN         NaN
# 1      NaN         NaN                NaN        NaN         NaN
# 2      NaN         NaN                NaN        NaN         NaN
# 3    13.24        2.59               21.0        NaN        2.69
# 4    14.20        1.76               15.2        NaN        3.39
#
#    proanthocyanins   hue
# 0              NaN   NaN
# 1              NaN   NaN
# 2              NaN   NaN
# 3             1.82  1.04
# 4             1.97  1.05

# %% [markdown]
# ### Step 8. Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
wine.loc[:,'alcohol'].fillna(10, inplace=True)
wine.loc[:,'magnesium'].fillna(100, inplace=True)

wine.head()
# Out:
# /tmp/ipython-input-733264626.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wine.loc[:,'alcohol'].fillna(10, inplace=True)
# /tmp/ipython-input-733264626.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# ### Step 9. Count the number of missing values

# %%
wine.isna().sum().sum()
# Out:
# np.int64(15)

# %% [markdown]
# ### Step 10.  Create an array of 10 random numbers up until 10

# %%
arr = np.random.randint(25, size=10)
print(arr)
# Out:
# [ 4  0  4  1 23  4 14 17 15  3]

# %% [markdown]
# ### Step 11.  Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
wine.iloc[arr] = np.nan
wine
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0        NaN         NaN                NaN        NaN         NaN
# 1        NaN         NaN                NaN        NaN         NaN
# 2      10.00         NaN                NaN      100.0         NaN
# 3        NaN         NaN                NaN        NaN         NaN
# 4        NaN         NaN                NaN        NaN         NaN
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0                NaN   NaN
# 1                NaN   NaN
# 2                NaN   NaN
# 3                NaN   NaN
# ...

# %% [markdown]
# ### Step 12.  How many missing values do we have?

# %%
wine.isna().sum().sum()
# Out:
# np.int64(61)

# %% [markdown]
# ### Step 13. Delete the rows that contain missing values

# %%
wine.dropna()
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 5      14.39        1.87               14.6       96.0        2.52
# 6      14.06        2.15               17.6      121.0        2.51
# 7      14.83        1.64               14.0       97.0        2.98
# 8      13.86        1.35               16.0       98.0        3.15
# 9      14.10        2.16               18.0      105.0        3.32
# ..       ...         ...                ...        ...         ...
# 172    13.71        5.65               20.5       95.0        0.61
# 173    13.40        3.91               23.0      102.0        0.75
# 174    13.27        4.28               20.0      120.0        0.69
# 175    13.17        2.59               20.0      120.0        0.68
# 176    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 5               1.98  1.02
# 6               1.25  1.06
# 7               1.98  1.08
# 8               1.85  1.01
# ...

# %% [markdown]
# ### Step 14. Print only the non-null values in alcohol

# %%
wine.alcohol.notnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 172     True
# 173     True
# 174     True
# 175     True
# 176     True
# Name: alcohol, Length: 177, dtype: bool

# %%
wine = wine.dropna()

# %% [markdown]
# ### Step 15.  Reset the index, so it starts with 0 again

# %%
wine.reset_index(drop=True)
# Out:
#      alcohol  malic_acid  alcalinity_of_ash  magnesium  flavanoids  \
# 0      14.39        1.87               14.6       96.0        2.52
# 1      14.06        2.15               17.6      121.0        2.51
# 2      14.83        1.64               14.0       97.0        2.98
# 3      13.86        1.35               16.0       98.0        3.15
# 4      14.10        2.16               18.0      105.0        3.32
# ..       ...         ...                ...        ...         ...
# 163    13.71        5.65               20.5       95.0        0.61
# 164    13.40        3.91               23.0      102.0        0.75
# 165    13.27        4.28               20.0      120.0        0.69
# 166    13.17        2.59               20.0      120.0        0.68
# 167    14.13        4.10               24.5       96.0        0.76
#
#      proanthocyanins   hue
# 0               1.98  1.02
# 1               1.25  1.06
# 2               1.98  1.08
# 3               1.85  1.01
# ...
