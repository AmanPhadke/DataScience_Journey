# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanPhadke/DataScience_Journey/blob/main/Phase1/Week4_Pandas_Advanced/Creating_your_own_DF/Pokemon/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
raw_data = pd.DataFrame({
    'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
    'hp': [45,39,44,45],
    'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
    'pokedex': ['yes', 'no', 'yes', 'no'],
    'type': ['grass', 'fire', 'water', 'bug']
})

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
pokemon = raw_data
pokemon
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
columns = ['name', 'type', 'hp', 'evolution', 'pokedex']
pokemon = pokemon[columns]
pokemon
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon['place'] = ['Indore', 'Bhopal', 'Mumbai', 'Goa']
pokemon
# Out:
#          name   type  hp   evolution pokedex   place
# 0   Bulbasaur  grass  45     Ivysaur     yes  Indore
# 1  Charmander   fire  39  Charmeleon      no  Bhopal
# 2    Squirtle  water  44   Wartortle     yes  Mumbai
# 3    Caterpie    bug  45     Metapod      no     Goa

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
pokemon.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex      object
# place        object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# Change the dtype of hp to obj

pokemon['hp'] = pokemon['hp'].astype('object')
pokemon.dtypes
# Out:
# name         object
# type         object
# hp           object
# evolution    object
# pokedex      object
# place        object
# dtype: object
